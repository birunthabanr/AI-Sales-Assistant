# %%
pip install transformers datasets
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from datasets import load_dataset
multiwoz = load_dataset("multi_woz_v22", trust_remote_code=True)  # Allow use of Python-based script
print(multiwoz['train'][0])
# Out:
# `trust_remote_code` is not supported anymore.
# Please check that the Hugging Face dataset 'multi_woz_v22' isn't based on a loading script and remove `trust_remote_code`.
# If the dataset is based on a loading script, please ask the dataset author to remove it and convert it to a standard format like Parquet.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 2
#       1 from datasets import load_dataset
# ----> 2 multiwoz = load_dataset("multi_woz_v22", trust_remote_code=True)  # Allow use of Python-based script
#       3 print(multiwoz['train'][0])
#
# File /opt/anaconda3/envs/tfenv/lib/python3.10/site-packages/datasets/load.py:1392, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
# ...
